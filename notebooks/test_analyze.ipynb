# %%
# get environment variables from .env file
import os
import requests
from environment_util import load_env_file
load_env_file("/Users/scooper/code/stock_advisor/.env")

BEARER_TOKEN = os.environ.get("BEARER_TOKEN")

# %%
import requests

# URL of the API endpoint
url = 'http://localhost:3333/analyze/'

# Parameters for the API call
params = {
    'symbol': 'PEP'
}

# Making a GET request to the API
response = requests.get(url, params=params)

# Checking if the request was successful
if response.status_code == 200:
    # Printing the response content
    print(response.json()["results"])
else:
    # Printing an error message if the request was not successful
    print(f"Failed to fetch data. Status code: {response.status_code}")
# Out:
# {"quarterly_income_statement": {"costOfGoodsSold": 10671, "dilutedAverageSharesOutstanding": 1383, "dilutedEPS": 2.23572, "ebit": 4045, "grossIncome": 12782, "interestIncomeExpense": -132, "minorityInterest": -24, "netIncome": 3092, "netIncomeAfterTaxes": 3116, "nonRecurringItems": -99, "period": "2023-09-09", "pretaxIncome": 3876, "provisionforIncomeTaxes": 760, "revenue": 23453, "sgaExpense": 8737, "totalOperatingExpense": 8737, "totalOtherIncomeExpenseNet": 62}, "quarterly_cash_flow": {"capex": -1024, "cashDividendsPaid": -1742, "changeinCash": 3889, "changesinWorkingCapital": 1629, "deferredTaxesInvestmentTaxCredit": 73, "depreciationAmortization": 705, "fcf": 4587, "foreignExchangeEffects": -110, "issuanceReductionCapitalStock": -284, "issuanceReductionDebtNet": 1388, "netCashFinancingActivities": -656, "netIncomeStartingLine": 3116, "netInvestingCashFlow": -956, "netOperatingCashFlow": 5611, "otherFundsFinancingItems": -18, "otherFundsNonCashItems": 88, "otherInvestingCashFlowItemsTotal": 68, "period": "2023-09-09"}, "quarterly_balance_sheet": {"accountsPayable": 23723, "accountsReceivables": 11782, "accumulatedDepreciation": -26732, "additionalPaidInCapital": 4154, "cashEquivalents": 10017, "cashShortTermInvestments": 10283, "commonStock": 23, "currentAssets": 28649, "currentLiabilities": 32660, "currentPortionLongTermDebt": 8937, "deferredIncomeTax": 4047, "goodwill": 17892, "intangiblesAssets": 15501, "inventory": 5558, "liabilitiesShareholdersEquity": 99953, "longTermDebt": 35837, "longTermInvestments": 2955, "minorityInterest": 164, "netDebt": 34491, "otherAssets": 17892, "otherCurrentAssets": 1026, "otherEquity": -15794, "otherLiabilities": 8439, "otherLongTermAssets": 10103, "otherReceivables": 0, "period": "2023-09-09", "propertyPlantEquipment": 24853, "retainedEarnings": 70479, "sharesOutstanding": 1375, "shortTermDebt": 0, "shortTermInvestments": 266, "tangibleBookValueperShare": -10.6087, "totalAssets": 99953, "totalDebt": 44774, "totalEquity": 18806, "totalLiabilities": 81147, "totalReceivables": 11782, "treasuryStock": -40056}, "annual_income_statement": {"costOfGoodsSold": 40202, "dilutedAverageSharesOutstanding": 1387, "dilutedEPS": 6.42, "ebit": 12490, "grossIncome": 46190, "interestIncomeExpense": -949, "minorityInterest": -68, "netIncome": 8910, "netIncomeAfterTaxes": 9064, "nonRecurringItems": -1312, "period": "2022-12-31", "pretaxIncome": 10705, "provisionforIncomeTaxes": 1641, "researchDevelopment": 771, "revenue": 86392, "sgaExpense": 32929, "totalOperatingExpense": 33700, "totalOtherIncomeExpenseNet": 476, "year": 2022}, "eps_estimates": {"epsAvg": 7.628277499999999, "epsHigh": 7.9799999999999995, "epsLow": 7.369599999999999, "numberAnalysts": 22, "period": "2023-12-31", "quarter": null, "year": 2023}, "price_target": {"lastUpdated": "2023-12-15 00:00:00", "numberAnalysts": 22, "symbol": "PEP", "targetHigh": 231, "targetLow": 152.51, "targetMean": 191.607, "targetMedian": 189.72}, "recommendation_trends": {"buy": 6, "hold": 12, "period": "2024-01-01", "sell": 1, "strongBuy": 7, "strongSell": 0, "symbol": "PEP"}, "dividends": [{"adjustedAmount": 1.075, "amount": 1.075, "currency": "USD", "date": "2022-03-03", "declarationDate": "2022-02-02", "franking": 0, "freq": "2", "payDate": "2022-03-31", "recordDate": "2022-03-04", "symbol": "PEP"}, {"adjustedAmount": 1.15, "amount": 1.15, "currency": "USD", "date": "2022-06-02", "declarationDate": "2022-05-03", "franking": 0, "freq": "2", "payDate": "2022-06-30", "recordDate": "2022-06-03", "symbol": "PEP"}, {"adjustedAmount": 1.15, "amount": 1.15, "currency": "USD", "date": "2022-09-01", "declarationDate": "2022-07-21", "franking": 0, "freq": "2", "payDate": "2022-09-30", "recordDate": "2022-09-02", "symbol": "PEP"}, {"adjustedAmount": 1.15, "amount": 1.15, "currency": "USD", "date": "2022-12-01", "declarationDate": "2022-11-17", "franking": 0, "freq": "2", "payDate": "2023-01-06", "recordDate": "2022-12-02", "symbol": "PEP"}, {"adjustedAmount": 1.15, "amoun ...
