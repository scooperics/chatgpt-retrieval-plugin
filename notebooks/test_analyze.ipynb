# %%
# get environment variables from .env file
import os
import requests
from environment_util import load_env_file
load_env_file("/Users/scooper/code/stock_advisor/.env")

BEARER_TOKEN = os.environ.get("BEARER_TOKEN")

# %%
import requests

# URL of the API endpoint
url = 'http://data.aitickerchat.com/analyze'

# Headers including the bearer token
headers = {
    'Authorization': f'Bearer {BEARER_TOKEN}'
}

# Parameters for the API call
params = {
    'symbol': 'AAPL'
}

# Making a GET request to the API
response = requests.get(url, headers=headers, params=params)

# Checking if the request was successful
if response.status_code == 200:
    # Printing the response content
    print("Response from API:", response.json()["results"])
else:
    # Printing an error message if the request was not successful
    print(f"Failed to fetch data. Status code: {response.status_code}")
# Out:
# Response from API: {"quarterly_income_statements": [{"costOfGoodsSold": 49071, "dilutedAverageSharesOutstanding": 15672, "dilutedEPS": 1.46, "ebit": 26969, "grossIncome": 40427, "interestIncomeExpense": -18, "netIncome": 22956, "netIncomeAfterTaxes": 22956, "period": "2023-09-30", "pretaxIncome": 26998, "provisionforIncomeTaxes": 4042, "researchDevelopment": 7307, "revenue": 89498, "sgaExpense": 6151, "totalOperatingExpense": 13458, "totalOtherIncomeExpenseNet": 47}, {"costOfGoodsSold": 45384, "dilutedAverageSharesOutstanding": 15775, "dilutedEPS": 1.26, "ebit": 22998, "grossIncome": 36413, "interestIncomeExpense": -18, "netIncome": 19881, "netIncomeAfterTaxes": 19881, "period": "2023-07-01", "pretaxIncome": 22733, "provisionforIncomeTaxes": 2852, "researchDevelopment": 7442, "revenue": 81797, "sgaExpense": 5973, "totalOperatingExpense": 13415, "totalOtherIncomeExpenseNet": -247}, {"costOfGoodsSold": 52860, "dilutedAverageSharesOutstanding": 15847, "dilutedEPS": 1.52, "ebit": 28318, "grossIncome": 41976, "interestIncomeExpense": -12, "netIncome": 24160, "netIncomeAfterTaxes": 24160, "period": "2023-04-01", "pretaxIncome": 28382, "provisionforIncomeTaxes": 4222, "researchDevelopment": 7457, "revenue": 94836, "sgaExpense": 6201, "totalOperatingExpense": 13658, "totalOtherIncomeExpenseNet": 76}, {"costOfGoodsSold": 66822, "dilutedAverageSharesOutstanding": 15956, "dilutedEPS": 1.88, "ebit": 36016, "grossIncome": 50332, "interestIncomeExpense": -135, "netIncome": 29998, "netIncomeAfterTaxes": 29998, "period": "2022-12-31", "pretaxIncome": 35623, "provisionforIncomeTaxes": 5625, "researchDevelopment": 7709, "revenue": 117154, "sgaExpense": 6607, "totalOperatingExpense": 14316, "totalOtherIncomeExpenseNet": -258}, {"costOfGoodsSold": 52051, "dilutedAverageSharesOutstanding": 16118, "dilutedEPS": 1.29, "ebit": 24894, "grossIncome": 38095, "interestIncomeExpense": -74, "netIncome": 20721, "netIncomeAfterTaxes": 20721, "period": "2022-09-24", "pretaxIncome": 24657, "provisionforIncomeTaxes": 3936, "researchDevelopment": 6761, "revenue": 90146, "sgaExpense": 6440, "totalOperatingExpense": 13201, "totalOtherIncomeExpenseNet": -163}], "quarterly_cash_flow": [{"capex": -2163, "cashDividendsPaid": -3758, "cashInterestPaid": 1213, "cashTaxesPaid": 11659, "changeinCash": 839, "changesinWorkingCapital": -6060, "depreciationAmortization": 2653, "fcf": 19435, "issuanceReductionCapitalStock": -21003, "issuanceReductionDebtNet": 1993, "netCashFinancingActivities": -23153, "netIncomeStartingLine": 22956, "netInvestingCashFlow": 2394, "netOperatingCashFlow": 21598, "otherFundsFinancingItems": -385, "otherFundsNonCashItems": 2049, "otherInvestingCashFlowItemsTotal": 4557, "period": "2023-09-30", "stockBasedCompensation": 2625}, {"capex": -2093, "cashDividendsPaid": -3849, "cashInterestPaid": 717, "cashTaxesPaid": 2126, "changeinCash": 2769, "changesinWorkingCapital": 749, "depreciationAmortization": 3052, "fcf": 24287, "issuanceReductionCapitalStock": -17478, "issuanceReductionDebtNet": -283, "netCashFinancingActivities": -24048, "netIncomeStartingLine": 19881, "netInvestingCashFlow": 437, "netOperatingCashFlow": 26380, "otherFundsFinancingItems": -2438, "otherFundsNonCashItems": 2698, "otherInvestingCashFlowItemsTotal": 2530, "period": "2023-07-01", "stockBasedCompensation": 2617}, {"capex": -2916, "cashDividendsPaid": -3650, "cashInterestPaid": 1170, "cashTaxesPaid": 4066, "changeinCash": 5155, "changesinWorkingCapital": 231, "depreciationAmortization": 2898, "fcf": 25644, "issuanceReductionCapitalStock": -19594, "issuanceReductionDebtNet": -1996, "netCashFinancingActivities": -25724, "netIncomeStartingLine": 24160, "netInvestingCashFlow": 2319, "netOperatingCashFlow": 28560, "otherFundsFinancingItems": -484, "otherFundsNonCashItems": 1271, "otherInvestingCashFlowItemsTotal": 5235, "period": "2023-04-01", "stockBasedCompensation": 2686}, {"capex": -3787, "cashDividendsPaid": -3768, "cashInterestPaid": 703, "cashTaxesPaid": 828, "changeinCash": -300 ...
