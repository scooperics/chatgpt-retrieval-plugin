# %%
# get environment variables from .env file
import os
import requests
from environment_util import load_env_file
load_env_file("/Users/scooper/code/stock_advisor/.env")

BEARER_TOKEN = os.environ.get("BEARER_TOKEN")

# %%
import requests

# URL of the API endpoint
url = 'http://localhost:3333/analyze/'

# Parameters for the API call
params = {
    'symbol': 'TSLA'
}

# Making a GET request to the API
response = requests.get(url, params=params)

# Checking if the request was successful
if response.status_code == 200:
    # Printing the response content
    print(response.json()["results"])
else:
    # Printing an error message if the request was not successful
    print(f"Failed to fetch data. Status code: {response.status_code}")
# Out:
# {"quarterly_income_statements": [{"costOfGoodsSold": 19172, "dilutedAverageSharesOutstanding": 3493, "dilutedEPS": 0.53, "ebit": 1764, "grossIncome": 4178, "interestIncomeExpense": 244, "minorityInterest": -27, "netIncome": 1851, "netIncomeAfterTaxes": 1878, "nonRecurringItems": 0, "period": "2023-09-30", "pretaxIncome": 2045, "provisionforIncomeTaxes": 167, "researchDevelopment": 1161, "revenue": 23350, "sgaExpense": 1253, "totalOperatingExpense": 2414, "totalOtherIncomeExpenseNet": 37}], "quarterly_cash_flow": [{"capex": -2459, "changeinCash": 711, "changesinWorkingCapital": -415, "depreciationAmortization": 1235, "fcf": 849, "foreignExchangeEffects": -98, "issuanceReductionCapitalStock": 254, "issuanceReductionDebtNet": 2064, "netCashFinancingActivities": 2263, "netIncomeStartingLine": 1878, "netInvestingCashFlow": -4762, "netOperatingCashFlow": 3308, "otherFundsFinancingItems": -55, "otherFundsNonCashItems": 610, "otherInvestingCashFlowItemsTotal": -2303, "period": "2023-09-30", "stockBasedCompensation": 465}], "quarterly_balance_sheet": [{"accountsPayable": 13937, "accountsReceivables": 2520, "accruedLiability": 6107, "accumulatedDepreciation": -12520, "additionalPaidInCapital": 34201, "cashEquivalents": 15932, "cashShortTermInvestments": 26077, "commonStock": 3, "currentAssets": 45026, "currentLiabilities": 26640, "currentPortionLongTermDebt": 1967, "goodwill": 250, "intangiblesAssets": 375, "inventory": 13721, "liabilitiesShareholdersEquity": 93941, "longTermDebt": 2426, "minorityInterest": 1029, "netDebt": -21684, "noteReceivableLongTerm": 535, "otherAssets": 250, "otherCurrentAssets": 2530, "otherCurrentliabilities": 4629, "otherEquity": -692, "otherLiabilities": 10380, "otherLongTermAssets": 4962, "otherReceivables": 178, "period": "2023-09-30", "propertyPlantEquipment": 42793, "retainedEarnings": 19954, "sharesOutstanding": 3179, "shortTermDebt": 0, "shortTermInvestments": 10145, "tangibleBookValueperShare": 16.6219, "totalAssets": 93941, "totalDebt": 4393, "totalEquity": 53466, "totalLiabilities": 40475, "totalReceivables": 2698}], "annual_income_statements": [{"costOfGoodsSold": 60609, "dilutedAverageSharesOutstanding": 3475, "dilutedEPS": 3.62, "ebit": 13832, "grossIncome": 20853, "interestIncomeExpense": 105, "minorityInterest": -4, "netIncome": 12583, "netIncomeAfterTaxes": 12587, "nonRecurringItems": -264, "period": "2022-12-31", "pretaxIncome": 13719, "provisionforIncomeTaxes": 1132, "researchDevelopment": 3075, "revenue": 81462, "sgaExpense": 3946, "totalOperatingExpense": 7021, "totalOtherIncomeExpenseNet": 46, "year": 2022}], "price_target": {"lastUpdated": "2023-12-15 00:00:00", "numberAnalysts": 42, "symbol": "TSLA", "targetHigh": 399, "targetLow": 24.57633, "targetMean": 228.242748, "targetMedian": 255}, "recommendation_trends": [{"buy": 15, "hold": 20, "period": "2024-01-01", "sell": 4, "strongBuy": 7, "strongSell": 4, "symbol": "TSLA"}, {"buy": 15, "hold": 21, "period": "2023-12-01", "sell": 4, "strongBuy": 7, "strongSell": 4, "symbol": "TSLA"}, {"buy": 15, "hold": 22, "period": "2023-11-01", "sell": 3, "strongBuy": 8, "strongSell": 4, "symbol": "TSLA"}, {"buy": 15, "hold": 21, "period": "2023-10-01", "sell": 3, "strongBuy": 8, "strongSell": 4, "symbol": "TSLA"}, {"buy": 15, "hold": 22, "period": "2023-09-01", "sell": 3, "strongBuy": 8, "strongSell": 4, "symbol": "TSLA"}], "dividends": [], "insider_transactions": [{"change": -4000, "filingDate": "2023-12-18", "id": "0001771340-23-000012", "isDerivative": true, "name": "Taneja Vaibhav", "share": 796920, "source": "sec", "symbol": "TSLA", "transactionCode": "M", "transactionDate": "2023-12-14", "transactionPrice": 0}, {"change": -4000, "filingDate": "2023-12-18", "id": "0001771340-23-000012", "isDerivative": false, "name": "Taneja Vaibhav", "share": 104930, "source": "sec", "symbol": "TSLA", "transactionCode": "S", "transactionDate": "2023-12-14", "transactionPrice": 250}, {"change": 4000, "filingDate": "2023-12-18", "id": "0001771340-23-000012", "isDer ...
